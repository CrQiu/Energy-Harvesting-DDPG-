# %%
"""
Deep Deterministic Policy Gradient (DDPG), Reinforcement Learning.
P2P network, net bit rate, energy harvesting example for training.
Thanks to : https://github.com/MorvanZhou/Reinforcement-learning-with-tensorflow/tree/master/contents/9_Deep_Deterministic_Policy_Gradient_DDPG
Using:
tensorflow 1.0
"""
import math
import tensorflow as tf
import numpy as np
import gym
import time
import EH_P2P
import DDPG_CLASS

np.random.seed(1)
tf.set_random_seed(1)



#####################  hyper parameters  ####################

MAX_EPISODES = 2000
MAX_EP_STEPS = 120
LR_A = 0.0002   # learning rate for actor
LR_C = 0.0002  # learning rate for critic
GAMMA = 0.999    # reward discount
REPLACEMENT = [
    dict(name='soft', tau=0.01),
    dict(name='hard', rep_iter_a=600, rep_iter_c=500)
][0]            # you can try different target replacement strategies
MEMORY_CAPACITY = 40000
BATCH_SIZE = 80

OUTPUT_GRAPH = False
    
env=EH_P2P.EH_P2P()
env.Chanpower()
env.Solarread()
    
state_dim = 3 #channel,battery，solar
action_dim = 1 #Transmission power
action_bound = 1 [0,1]

tip=1
tip2=1
snr=-10

for temp in range(1):
   #for snr in range(-10,10,2):
    for modulation in range(1):
        var = 10

        tf.reset_default_graph()
        sess = tf.Session()
        with tf.name_scope('S'):
            S = tf.placeholder(tf.float32, shape=[None, state_dim], name='s')
        with tf.name_scope('R'):
            R = tf.placeholder(tf.float32, [None, 1], name='r')
        with tf.name_scope('S_'):
            S_ = tf.placeholder(tf.float32, shape=[None, state_dim], name='s_')
        DDPG_CLASS.S=S
        DDPG_CLASS.R=R
        DDPG_CLASS.S_=S_
        actor = DDPG_CLASS.Actor(sess, action_dim, action_bound, LR_A, REPLACEMENT)
        critic = DDPG_CLASS.Critic(sess, state_dim, action_dim, LR_C, GAMMA, REPLACEMENT, actor.a, actor.a_)
        actor.add_grad_to_graph(critic.a_grads)
        M = DDPG_CLASS.Memory(MEMORY_CAPACITY, dims=2 * state_dim + action_dim + 1)


        sess.run(tf.global_variables_initializer())
        saver=tf.train.Saver(max_to_keep=100)

        if OUTPUT_GRAPH:
            tf.summary.FileWriter("logs/", sess.graph)

        print("modulation=",modulation,"snr=",snr)

        for i in range(MAX_EPISODES):
    
            s = env.reset_P2P(snr)

            ep_reward = 0
            for j in range(MAX_EP_STEPS):
                a = actor.choose_action(s)
                a = np.random.normal(a, var)
                a=np.clip(a,0,1)
                s_, r, info = env.step_P2P([a,modulation])#input modulation 0:qpsk,1:8psk,2:16qam

                M.store_transition(s, a, r , s_)

                if M.pointer > MEMORY_CAPACITY:
                    #tip and tip2 are only for printing`#
                    if tip == 1:
                        print("memory full",j,i)
                        tip=0
                    var *= 0.9995  # decay the action randomness
                    if tip2 == 1 and var<0.00000001:
                        print("var zero",j,i)
                        tip2=0
                        
                    b_M = M.sample(BATCH_SIZE)
                    b_s = b_M[:, :state_dim]
                    b_a = b_M[:, state_dim: state_dim + action_dim]
                    b_r = b_M[:, -state_dim - 1: -state_dim]
                    b_s_ = b_M[:, -state_dim:]

                    critic.learn(b_s, b_a, b_r, b_s_)
                    actor.learn(b_s)

                s = s_
                
                ep_reward += r


            if i % 30 == 0 :
                print("net bit rate=",r,"action",a, "solar,channel,battery",s,"epoch",i)
                print("ave_reward",ep_reward/(j+1))
                
                
                
        save_path = saver.save(sess, "folder_for_nn_noise"+"/EH_save_net_snr="+str(snr)+str(modulation)+"epoch="+str(i)+"_P2P.ckpt")
        print("Save to path: ", save_path)

print("----------------------------END--------------------------------")
# Out:
# modulation= 0 snr= -10
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([0.193472])]
# ave_reward 10494.200864050617
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=0_1way.ckpt
# 10582.387425933395 0
#
# net bit rate= 167221.96207069396 action [1.] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([0.193472])]
# ave_reward 8965.952927497052
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=30_1way.ckpt
# 9041.297069744927 30
#
# net bit rate= 0.0 action [0.] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([0.649872])]
# ave_reward 13271.149015774807
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=60_1way.ckpt
# 13382.67127641157 60
#
# net bit rate= 10.269756120306216 action [0.945073] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([0.20963328])]
# ave_reward 5678.144522168757
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=90_1way.ckpt
# 5725.860022355049 90
#
# net bit rate= 0.0 action [0.] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([0.487704])]
# ave_reward 9676.798257894041
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=120_1way.ckpt
# 9758.11589031332 120
#
# net bit rate= 77759.15947420071 action [1.] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([0.193472])]
# ave_reward 13321.564200328747
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=150_1way.ckpt
# 13433.510117978567 150
#
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([0.193472])]
# ave_reward 9380.833288530454
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=180_1way.ckpt
# 9459.663820366844 180
#
# net bit rate= 0.0 action [0.] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([0.487704])]
# ave_reward 13472.79990221824
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=210_1way.ckpt
# 13586.016708119232 210
#
# net bit rate= 0.0 action [0.] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([0.649872])]
# ave_reward 13556.41657907144
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=240_1way.ckpt
# 13670.33604612246 240
#
# net bit rate= 0.0 action [0.] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([0.487704])]
# ave_reward 11191.106881894431
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=270_1way.ckpt
# 11285.149796868334 270
#
# net bit rate= 0.0 action [0.] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([0.649872])]
# ave_reward 14092.456933598094
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=300_1way.ckpt
# 14210.880941443456 300
#
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([0.193472])]
# ave_reward 10948.98561814275
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=330_1way.ckpt
# 11040.993900648149 330
#
# !!!
# memory full 40 333
# net bit rate= 45774.95358184307 action [1.] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([0.193472])]
# ave_reward 13437.664845348298
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=360_1way.ckpt
# 13550.586398670552 360
#
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([0.193472])]
# ave_reward 13983.468747828709
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=390_1way.ckpt
# 14100.976888566765 390
#
# net bit rate= 500.12789776150606 action [0.86651108] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([0.2420606])]
# ave_reward 5729.106326375755
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=420_1way.ckpt
# 5777.250077017568 420
#
# net bit rate= 2583.971489070867 action [0.22056591] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.39335059])]
# ave_reward 9648.358236722897
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=450_1way.ckpt
# 9729.436877367627 450
#
# net bit rate= 874.8850532662593 action [0.17439064] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.72154295])]
# ave_reward 10975.82383198398
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=480_1way.ckpt
# 11068.05764569813 480
#
# net bit rate= 199908.06777762703 action [0.80554333] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([0.44968291])]
# ave_reward 14704.868242129098
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=510_1way.ckpt
# 14828.438563491527 510
#
# net bit rate= 0.0 action [5.1335631e-05] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.88329846])]
# ave_reward 10204.312060017222
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=540_1way.ckpt
# 10290.062581529972 540
#
# net bit rate= 0.0 action [0.00018756] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([2.04597754])]
# ave_reward 5352.085493408324
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=570_1way.ckpt
# 5397.061001756293 570
#
# net bit rate= 0.0 action [6.57405846e-06] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.93384014])]
# ave_reward 7599.581539725661
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=600_1way.ckpt
# 7663.443569471255 600
#
# net bit rate= 199622.67384326612 action [0.78671658] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([0.45042803])]
# ave_reward 13920.314770789659
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=630_1way.ckpt
# 14037.29220583831 630
#
# net bit rate= 199655.75256518263 action [0.9565293] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([0.23688113])]
# ave_reward 13196.139065012083
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=660_1way.ckpt
# 13307.030989928151 660
#
# !!!
# var zero 76 678
# net bit rate= 199254.07437137834 action [0.98663736] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([0.20556817])]
# ave_reward 12656.035746103267
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=690_1way.ckpt
# 12762.38898766716 690
#
# net bit rate= 199882.5317713532 action [0.99531484] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([0.19837515])]
# ave_reward 14238.149163861468
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=720_1way.ckpt
# 14357.797476162825 720
#
# net bit rate= 199936.3330953028 action [0.98128718] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([0.21427639])]
# ave_reward 13461.608796806217
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=750_1way.ckpt
# 13574.731559804588 750
#
# net bit rate= 179017.83604806883 action [0.54667526] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([0.71072076])]
# ave_reward 15012.50939993399
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=780_1way.ckpt
# 15138.664941109904 780
#
# net bit rate= 2.1468679735058202e-79 action [0.05921273] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.36252346])]
# ave_reward 13391.585612621471
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=810_1way.ckpt
# 13504.119945500643 810
#
# net bit rate= 0.0 action [0.00017092] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.89791878])]
# ave_reward 14883.785169825396
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=840_1way.ckpt
# 15008.858994781913 840
#
# net bit rate= 0.0 action [0.00019119] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.90193797])]
# ave_reward 14817.6177184789
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=870_1way.ckpt
# 14942.135514432504 870
#
# net bit rate= 0.0 action [0.00020321] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.90091291])]
# ave_reward 15206.161987847632
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=900_1way.ckpt
# 15333.944861695092 900
#
# net bit rate= 0.0 action [3.14413446e-05] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.90521683])]
# ave_reward 15109.459664985558
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=930_1way.ckpt
# 15236.42991427115 930
#
# net bit rate= 0.0 action [0.00069593] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.90626235])]
# ave_reward 15376.28470630461
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=960_1way.ckpt
# 15505.497182828178 960
#
# net bit rate= 0.0 action [3.33861044e-08] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.91429806])]
# ave_reward 13802.418081894568
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=990_1way.ckpt
# 13918.40478846511 990
#
# net bit rate= 0.0 action [1.63068861e-11] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.91554045])]
# ave_reward 13485.683795123145
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=1020_1way.ckpt
# 13599.00886903174 1020
#
# net bit rate= 0.0 action [8.8798157e-11] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.91564956])]
# ave_reward 13901.223029812045
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=1050_1way.ckpt
# 14018.040030062566 1050
#
# net bit rate= 0.0 action [3.80107966e-13] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.91572262])]
# ave_reward 13849.251990019447
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=1080_1way.ckpt
# 13965.63225884314 1080
#
# net bit rate= 0.0 action [1.35101817e-17] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.91579382])]
# ave_reward 13607.792793701612
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=1110_1way.ckpt
# 13722.143993648684 1110
#
# net bit rate= 0.0 action [5.52756886e-19] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.91587101])]
# ave_reward 13741.042173417221
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=1140_1way.ckpt
# 13856.513116050979 1140
#
# net bit rate= 0.0 action [1.20216948e-21] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.91586548])]
# ave_reward 13332.628365951752
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=1170_1way.ckpt
# 13444.667259783278 1170
#
# net bit rate= 0.0 action [0.] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.91586577])]
# ave_reward 13106.398661221405
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=1200_1way.ckpt
# 13216.536465097215 1200
#
# net bit rate= 0.0 action [2.66520963e-23] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.91586755])]
# ave_reward 13665.961533973083
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=1230_1way.ckpt
# 13780.801546863613 1230
#
# net bit rate= 0.0 action [2.8721842e-24] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.91587084])]
# ave_reward 12622.423566951276
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=1260_1way.ckpt
# 12728.494353228178 1260
#
# net bit rate= 0.0 action [9.87767024e-23] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.91586284])]
# ave_reward 13084.61927114292
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=1290_1way.ckpt
# 13194.574054934035 1290
#
# net bit rate= 0.0 action [1.6524402e-20] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.91585309])]
# ave_reward 13824.138499211704
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=1320_1way.ckpt
# 13940.307730297516 1320
#
# net bit rate= 0.0 action [6.00311515e-26] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.91588051])]
# ave_reward 12807.486777171851
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=1350_1way.ckpt
# 12915.112716475816 1350
#
# net bit rate= 0.0 action [0.] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.91588838])]
# ave_reward 12884.043535827068
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=1380_1way.ckpt
# 12992.312809237379 1380
#
# net bit rate= 0.0 action [0.] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.91588563])]
# ave_reward 12779.922220256263
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=1410_1way.ckpt
# 12887.316524628164 1410
#
# net bit rate= 0.0 action [1.2622876e-28] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.9158855])]
# ave_reward 12783.028261146204
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=1440_1way.ckpt
# 12890.448666702054 1440
#
# net bit rate= 0.0 action [0.] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.91588595])]
# ave_reward 12866.240140860198
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=1470_1way.ckpt
# 12974.359805909444 1470
#
# net bit rate= 0.0 action [4.19325074e-21] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([2.15897662])]
# ave_reward 12538.322797350333
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=1500_1way.ckpt
# 12643.686854470925 1500
#
# net bit rate= 0.0 action [6.33208996e-23] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([2.17791337])]
# ave_reward 12543.74127115042
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=1530_1way.ckpt
# 12649.15086166429 1530
#
# net bit rate= 0.0 action [1.69575237e-21] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([2.2243921])]
# ave_reward 12535.432081878625
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=1560_1way.ckpt
# 12640.771847272565 1560
#
# net bit rate= 0.0 action [0.] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.63932578])]
# ave_reward 12143.492909429653
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=1590_1way.ckpt
# 12245.539068332424 1590
#
# net bit rate= 0.0 action [2.34211369e-33] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.91592207])]
# ave_reward 12493.61071553636
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=1620_1way.ckpt
# 12598.599040877001 1620
#
# net bit rate= 0.0 action [1.68071144e-34] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.915888])]
# ave_reward 12637.738985904669
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=1650_1way.ckpt
# 12743.938473181179 1650
#
# net bit rate= 0.0 action [4.52136817e-35] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.915888])]
# ave_reward 12179.793367316144
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=1680_1way.ckpt
# 12282.144572083507 1680
#
# net bit rate= 0.0 action [4.04857419e-36] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.915888])]
# ave_reward 12458.603016089048
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=1710_1way.ckpt
# 12563.297159081394 1710
#
# net bit rate= 0.0 action [1.29145064e-36] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.915888])]
# ave_reward 13057.475558438013
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=1740_1way.ckpt
# 13167.202243803038 1740
#
# net bit rate= 0.0 action [0.] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.915888])]
# ave_reward 13067.397877157764
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=1770_1way.ckpt
# 13177.207943352369 1770
#
# net bit rate= 0.0 action [1.77105503e-38] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.915888])]
# ave_reward 13088.186329057253
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=1800_1way.ckpt
# 13198.17108812496 1800
#
# net bit rate= 0.0 action [6.30737489e-39] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.63920019])]
# ave_reward 12361.828652449518
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=1830_1way.ckpt
# 12465.709565495314 1830
#
# net bit rate= 0.0 action [3.81944664e-39] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([2.14797576])]
# ave_reward 12674.370361305047
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=1860_1way.ckpt
# 12780.877675265594 1860
#
# net bit rate= 0.0 action [0.] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([2.18007214])]
# ave_reward 12034.955947754117
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=1890_1way.ckpt
# 12136.090031348689 1890
#
# net bit rate= 0.0 action [1.90916278e-41] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.92361105])]
# ave_reward 12263.650862789471
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=1920_1way.ckpt
# 12366.706752392744 1920
#
# net bit rate= 0.0 action [3.4378364e-42] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.92635015])]
# ave_reward 12262.70413823852
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=1950_1way.ckpt
# 12365.752072173298 1950
#
# net bit rate= 0.0 action [1.40744446e-42] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.9187159])]
# ave_reward 13219.6861141693
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=1980_1way.ckpt
# 13330.775913448033 1980
#
# net bit rate= 0.0 action [1.49245698e-43] solar,channel,battery [array([0.035152]) -0.42827632965626994 array([0.245816])] 0.0
# net bit rate= 0.0 action [1.40262856e-12] solar,channel,battery [array([0.050768]) -0.6728105373876961 array([0.380968])] 0.0
# net bit rate= 1.691062904128862e-118 action [1.] solar,channel,battery [array([0.063544]) -0.8609668415980516 array([0.150768])] 5.636876347096206e-119
# net bit rate= 0.0 action [1.] solar,channel,battery [array([0.0804]) -0.9538684419873621 array([0.163544])] 4.227657260322155e-119
# net bit rate= 0.0 action [1.] solar,channel,battery [array([0.12696]) -0.940146197845513 array([0.1804])] 3.382125808257724e-119
# net bit rate= 0.0 action [1.] solar,channel,battery [array([0.222672]) -0.8374499546579695 array([0.22696])] 2.818438173548103e-119
# net bit rate= 6.417901291124145e-271 action [1.] solar,channel,battery [array([0.272752]) -0.6858882138440547 array([0.322672])] 2.415804148755517e-119
# net bit rate= 7.480584652878008e-144 action [0.9995622] solar,channel,battery [array([0.280624]) -0.5358418848557952 array([0.37289326])] 2.1138286301610775e-119
# net bit rate= 0.0 action [7.37361672e-10] solar,channel,battery [array([0.217136]) -0.4338664331848918 array([0.75351726])] 1.8789587823654022e-119
# net bit rate= 1.7679178595344597e-12 action [1.] solar,channel,battery [array([0.204552]) -0.41049665637884925 array([0.317136])] 1.7679178595344596e-13
# net bit rate= 0.0 action [6.21670982e-21] solar,channel,battery [array([0.16292]) -0.4728601332772623 array([0.621688])] 1.6071980541222362e-13
# net bit rate= 1.750068508198119e-26 action [0.99999988] solar,channel,battery [array([0.226736]) -0.6035044222093138 array([0.26292007])] 1.4732648829453978e-13
# net bit rate= 0.0 action [2.25889357e-06] solar,channel,battery [array([0.280072]) -0.7652389154347392 array([0.58965548])] 1.359936815026521e-13
# net bit rate= 3.764138352566129e-106 action [1.] solar,channel,battery [array([0.262168]) -0.910484995875178 array([0.380072])] 1.2627984710960552e-13
# net bit rate= 1.3999309439723176e-280 action [1.] solar,channel,battery [array([0.269648]) -0.9928365928656622 array([0.362168])] 1.1786119063563182e-13
# net bit rate= 0.0 action [1.] solar,channel,battery [array([0.340192]) -0.978291710062378 array([0.369648])] 1.1049486622090483e-13
# net bit rate= 0.0 action [1.] solar,channel,battery [array([0.324896]) -0.8538369372502804 array([0.440192])] 1.0399516820791044e-13
# net bit rate= 1.5458034453168687e-201 action [1.] solar,channel,battery [array([0.308992]) -0.6316265347597402 array([0.424896])] 9.821765886302652e-14
# net bit rate= 2.298423427221421e-96 action [0.96353292] solar,channel,battery [array([0.210648]) -0.3477913598324195 array([0.42448671])] 9.304830839655143e-14
# net bit rate= 0.0 action [1.96058951e-21] solar,channel,battery [array([0.166576]) -0.0558665570537803 array([0.73513471])] 8.839589297672387e-14
# net bit rate= 0.0 action [4.48328174e-29] solar,channel,battery [array([0.158472]) 0.18413780948023883 array([1.00171071])] 8.418656473973701e-14
# net bit rate= 0.0 action [1.68116996e-36] solar,channel,battery [array([0.148464]) 0.3190110737452938 array([1.26018271])] 8.03599027061126e-14
# net bit rate= 0.0 action [8.51596708e-34] solar,channel,battery [array([0.143408]) 0.3152078634001869 array([1.50864671])] 7.686599389280336e-14
# net bit rate= 0.0 action [3.79028715e-18] solar,channel,battery [array([0.144768]) 0.1682952276675076 array([1.75205471])] 7.366324414726989e-14
# net bit rate= 198791.67334160183 action [1.] solar,channel,battery [array([0.210936]) -0.09360826714733572 array([0.244768])] 7951.666933664073
# net bit rate= 0.0 action [1.20096553e-43] solar,channel,battery [array([0.19036]) -0.41384285328069403 array([0.555704])] 7645.833590061608
# net bit rate= 0.0 action [8.32654587e-06] solar,channel,battery [array([0.165584]) -0.7184029656115061 array([0.84605937])] 7362.654568207475
# net bit rate= 2.0282413611584866e-50 action [1.] solar,channel,battery [array([0.137624]) -0.9321781295673164 array([0.265584])] 7099.702619342922
# net bit rate= 0.0 action [1.] solar,channel,battery [array([0.12624]) -0.9965752739285073 array([0.237624])] 6854.885287641442
# net bit rate= 0.0 action [1.] solar,channel,battery [array([0.177304]) -0.8841807759313527 array([0.22624])] 6626.389111386728
# net bit rate= 1.1595612803957e-310 action [1.] solar,channel,battery [array([0.201712]) -0.6065866382912339 array([0.277304])] 6412.63462392264
# net bit rate= 0.0 action [0.00041771] solar,channel,battery [array([0.223984]) -0.2130856043418604 array([0.57890017])] 6212.239791925057
# net bit rate= 0.0 action [1.29085455e-26] solar,channel,battery [array([0.255216]) 0.21974676269418292 array([0.90288417])] 6023.9901012606615
# net bit rate= 0.0 action [0.] solar,channel,battery [array([0.284064]) 0.6051570842116065 array([1.25810017])] 5846.813921811819
# net bit rate= 0.0 action [6.80687607e-44] solar,channel,battery [array([0.364408]) 0.8657804278105268 array([1.64216417])] 5679.762095474338
# net bit rate= 0.0 action [0.] solar,channel,battery [array([0.407152]) 0.9507917899999443 array([2.10657217])] 5521.990926155606
# net bit rate= 0.0 action [0.] solar,channel,battery [array([0.324312]) 0.8464656451250574 array([2.61372417])] 5372.747928151401
# net bit rate= 0.0 action [5.0040139e-16] solar,channel,battery [array([0.270336]) 0.5778008821642007 array([3.03803617])] 5231.359824778995
# net bit rate= 199999.9991184385 action [1.] solar,channel,battery [array([0.252216]) 0.20127924808316822 array([0.370336])] 10225.427498975392
# net bit rate= 0.0 action [0.] solar,channel,battery [array([0.301192]) -0.20890915743634986 array([0.722552])] 9969.791811501007
# net bit rate= 0.0 action [4.30603638e-23] solar,channel,battery [array([0.307112]) -0.5773679206548807 array([1.123744])] 9726.62615756196
# net bit rate= 3.0032345724788604e-08 action [1.] solar,channel,battery [array([0.284928]) -0.8426089332698472 array([0.407112])] 9495.039820477865
# net bit rate= 4.613036980812058e-202 action [1.] solar,channel,battery [array([0.331624]) -0.9675020721328309 array([0.384928])] 9274.224940931868
# net bit rate= 0.0 action [1.] solar,channel,battery [array([0.43228]) -0.9433973702794156 array([0.431624])] 9063.447101365235
# net bit rate= 1.976263e-318 action [1.] solar,channel,battery [array([0.412928]) -0.788075106584172 array([0.53228])] 8862.03716577934
# net bit rate= 1.4111087433583057e-130 action [1.] solar,channel,battery [array([0.32876]) -0.5391304346906521 array([0.512928])] 8669.384183914573
# net bit rate= 0.0 action [0.00031997] solar,channel,battery [array([0.28532]) -0.24511028120790535 array([0.94152388])] 8484.929201278092
# net bit rate= 0.0 action [5.64248694e-05] solar,channel,battery [array([0.242104]) 0.04337961327393991 array([1.32679075])] 8308.159842918132
# net bit rate= 0.0 action [8.20813e-08] solar,channel,battery [array([0.42176]) 0.2810722964740322 array([1.66889465])] 8138.605560409599
# net bit rate= 0.0 action [2.09340662e-22] solar,channel,battery [array([0.206984]) 0.4333139403096762 array([2.19065465])] 7975.833449201407
# net bit rate= 199995.79817251072 action [1.] solar,channel,battery [array([0.212152]) 0.47930241095749726 array([0.306984])] 11740.930796717275
# net bit rate= 0.0 action [0.] solar,channel,battery [array([0.096568]) 0.41367971803923087 array([0.619136])] 11515.143666011174
# net bit rate= 0.0 action [0.] solar,channel,battery [array([0.226208]) 0.2467563238786692 array([0.815704])] 11297.876804388321
# net bit rate= 0.0 action [3.04209212e-43] solar,channel,battery [array([0.24992]) 0.0033222044823637553 array([1.141912])] 11088.656863566315
# net bit rate= 0.0 action [1.15164294e-15] solar,channel,battery [array([0.249312]) -0.2802435450207241 array([1.491832])] 10887.044920592383
# net bit rate= 69980.27552534238 action [1.] solar,channel,battery [array([0.220608]) -0.5607828946618948 array([0.349312])] 11942.28118139149
# net bit rate= 0.0 action [7.55127403e-05] solar,channel,battery [array([0.206088]) -0.7948659231598499 array([0.66989362])] 11732.767476454797
# net bit rate= 5.318814060928798e-107 action [1.] solar,channel,battery [array([0.223264]) -0.9461097316137697 array([0.306088])] 11530.478382033163
# net bit rate= 0.0 action [1.] solar,channel,battery [array([0.183888]) -0.9918388172652985 array([0.323264])] 11335.04654504955
# net bit rate= 0.0 action [1.] solar,channel,battery [array([0.190424]) -0.9274196409837738 array([0.283888])] 11146.129102632058
# net bit rate= 0.0 action [1.] solar,channel,battery [array([0.182896]) -0.7669746162331016 array([0.290424])] 10963.405674720058
# net bit rate= 4.472777888555408e-195 action [1.] solar,channel,battery [array([0.271024]) -0.5400768157560277 array([0.282896])] 10786.57655093425
# net bit rate= 0.0 action [4.41694987e-14] solar,channel,battery [array([0.70424]) -0.28517230713102815 array([0.65392])] 10615.36105012577
# net bit rate= 0.0 action [0.] solar,channel,battery [array([0.88456]) -0.04146678481025279 array([1.45816])] 10449.496033717554
# net bit rate= 0.0 action [1.62519073e-32] solar,channel,battery [array([0.77592]) 0.1585310208513897 array([2.44272])] 10288.734556275745
# net bit rate= 199979.21832819836 action [1.] solar,channel,battery [array([0.39188]) 0.2938890881646934 array([0.87592])] 13162.83279524427
# net bit rate= 0.0 action [0.] solar,channel,battery [array([0.561048]) 0.356557196424127 array([1.3678])] 12966.372604270477
# net bit rate= 0.0 action [2.05257061e-43] solar,channel,battery [array([0.45448]) 0.34933916455844494 array([2.028848])] 12775.690654207676
# net bit rate= 0.0 action [1.63935587e-10] solar,channel,battery [array([0.608032]) 0.28186701229864086 array([2.583328])] 12590.535717190172
# net bit rate= 199998.26253519946 action [1.] solar,channel,battery [array([0.79216]) 0.16644346233101426 array([0.708032])] 15267.788957447448
# net bit rate= 0.0 action [2.7429523e-43] solar,channel,battery [array([0.687136]) 0.015391263909440678 array([1.600192])] 15052.74967635664
# net bit rate= 0.0 action [1.70205514e-17] solar,channel,battery [array([0.61024]) -0.15933629465604893 array([2.387328])] 14843.683708629464
# net bit rate= 198511.91921287775 action [1.] solar,channel,battery [array([0.680232]) -0.34469881757705934 array([0.71024])] 17359.686934715057
# net bit rate= 0.0 action [2.55374013e-34] solar,channel,battery [array([0.43556]) -0.5246418837900655 array([1.490472])] 17125.09657073242
# net bit rate= 82.93793644838571 action [1.] solar,channel,battery [array([0.426896]) -0.6794080484964884 array([0.53556])] 16897.86778894197
# net bit rate= 3.608817373566095e-82 action [0.99999762] solar,channel,battery [array([0.406072]) -0.7873295828904018 array([0.52689728])] 16675.527423297997
# net bit rate= 2.1643198226195374e-131 action [1.] solar,channel,battery [array([0.420968]) -0.8292455350141452 array([0.506072])] 16458.962132086333
# net bit rate= 7.052555274340277e-164 action [1.] solar,channel,battery [array([0.369776]) -0.7943849734305364 array([0.520968])] 16247.949797059586
# net bit rate= 6.206319405658082e-137 action [1.] solar,channel,battery [array([0.4272]) -0.6856052010322988 array([0.469776])] 16042.279546463895
# net bit rate= 1.8205798839424068e-99 action [0.99346888] solar,channel,battery [array([0.399832]) -0.5217061240554898 array([0.53026816])] 15841.751052133095
# net bit rate= 0.0 action [9.78531256e-10] solar,channel,battery [array([0.478224]) -0.33530368911416975 array([1.03010016])] 15646.173878649972
# net bit rate= 0.0 action [0.00139874] solar,channel,battery [array([0.53244]) -0.16621175381464393 array([1.60688332])] 15455.36688012985
# net bit rate= 155463.24424600796 action [1.] solar,channel,battery [array([0.687624]) -0.051929873347645095 array([0.63244])] 17142.208776104282
# net bit rate= 0.0 action [2.15564561e-43] solar,channel,battery [array([0.302984]) -0.01803513321296224 array([1.420064])] 16938.13486210304
# net bit rate= 1.3061839314303973e-06 action [0.35738418] solar,channel,battery [array([0.236288]) -0.07153722523274708 array([1.3155396])] 16738.86268727014
# net bit rate= 124176.21594333401 action [0.99925727] solar,channel,battery [array([0.478136]) -0.19942181441969065 array([0.3372651])] 17988.13423675925
# net bit rate= 0.0 action [3.71503146e-43] solar,channel,battery [array([0.299432]) -0.37293419560245566 array([0.9154011])] 17781.374073118342
# net bit rate= 0.011743453353115512 action [0.9999963] solar,channel,battery [array([0.42248]) -0.5562289867721225 array([0.39943538])] 17579.313137553967
# net bit rate= 0.0 action [1.19717202e-15] solar,channel,battery [array([0.61332]) -0.7165336707602189 array([0.92191538])] 17381.792765221897
# net bit rate= 1.0348422635206266e-42 action [1.] solar,channel,battery [array([0.424448]) -0.8324963537125001 array([0.71332])] 17188.66173449721
# net bit rate= 1.3913281150302811e-123 action [1.] solar,channel,battery [array([0.36576]) -0.8980991096939935 array([0.524448])] 16999.77534181043
# net bit rate= 3.9449011069806644e-225 action [1.] solar,channel,battery [array([0.262744]) -0.9211618484583953 array([0.46576])] 16814.99517505162
# net bit rate= 1.7529226613395597e-271 action [1.] solar,channel,battery [array([0.201136]) -0.9174279783459087 array([0.362744])] 16634.188775319883
# net bit rate= 1.8068692472739129e-295 action [1.] solar,channel,battery [array([0.313264]) -0.90277671445982 array([0.301136])] 16457.229320263286
# net bit rate= 4.312333446506574e-298 action [1.] solar,channel,battery [array([0.249368]) -0.8866669635839223 array([0.413264])] 16283.99532741841
# net bit rate= 1.0981243670844627e-241 action [1.] solar,channel,battery [array([0.140504]) -0.8692829313867696 array([0.349368])] 16114.370376091136
# net bit rate= 7.932708947047232e-245 action [1.] solar,channel,battery [array([0.223992]) -0.843280146041077 array([0.240504])] 15948.242846440711
# net bit rate= 2.445296153352283e-268 action [1.] solar,channel,battery [array([0.29188]) -0.7991425556065375 array([0.323992])] 15785.505674538255
# net bit rate= 4.395109214187144e-200 action [1.] solar,channel,battery [array([0.289672]) -0.7316988250779627 array([0.39188])] 15626.05612227019
# net bit rate= 3.075379735633766e-139 action [1.] solar,channel,battery [array([0.3376]) -0.6448832171861131 array([0.389672])] 15469.79556104749
# net bit rate= 0.0 action [0.08512489] solar,channel,battery [array([0.44948]) -0.5525436024999155 array([0.79410121])] 15316.629268363851
# net bit rate= 1.259598004930228e-21 action [0.99999976] solar,channel,battery [array([0.429832]) -0.4747093714771803 array([0.54948019])] 15166.466236321068
# net bit rate= 0.0 action [2.29599271e-15] solar,channel,battery [array([0.22836]) -0.4305930343137967 array([1.07931219])] 15019.218991308242
# net bit rate= 0.36390503954113884 action [1.] solar,channel,battery [array([0.221344]) -0.43096714022857574 array([0.32836])] 14874.806923171043
# net bit rate= 0.0 action [1.20349312e-19] solar,channel,battery [array([0.152928]) -0.47288381083152753 array([0.649704])] 14733.142095331319
# net bit rate= 8.900160524511706e-24 action [1.] solar,channel,battery [array([0.241768]) -0.5388548329811879 array([0.252928])] 14594.150188771591
# net bit rate= 0.0 action [1.81952265e-14] solar,channel,battery [array([0.34396]) -0.6009251162126603 array([0.594696])] 14457.756261773726
# net bit rate= 9.370881742236654e-51 action [0.9999994] solar,channel,battery [array([0.377712]) -0.628228107931541 array([0.44396035])] 14323.888148238782
# net bit rate= 0.0 action [0.00860055] solar,channel,battery [array([0.425896]) -0.5953492533673729 array([0.91785405])] 14192.476330365032
# net bit rate= 3.5235037678609323e-19 action [1.] solar,channel,battery [array([0.176688]) -0.48864438988658554 array([0.525896])] 14063.453818270806
# net bit rate= 1.2525542754311242e-43 action [0.96077269] solar,channel,battery [array([0.056288]) -0.30861733272599756 array([0.29731748])] 13936.756036124221
# net bit rate= 0.0 action [2.19582099e-23] solar,channel,battery [array([0.108288]) -0.06813314768047063 array([0.45360548])] 13812.320714373112
# net bit rate= 0.0 action [0.] solar,channel,battery [array([-0.021544]) 0.21209412872677103 array([0.66189348])] 13690.087787697244
# net bit rate= 0.0 action [1.62669705e-44] solar,channel,battery [array([-0.011432]) 0.5083719074932476 array([0.74034948])] 13569.999298331479
# net bit rate= 0.0 action [0.] solar,channel,battery [array([0.228056]) 0.7971041125095557 array([0.82891748])] 13451.999304432944
# net bit rate= 0.0 action [2.92030573e-43] solar,channel,battery [array([0.029672]) 1.0551779942496902 array([1.15697348])] 13336.033793187833
# net bit rate= 0.0 action [5.09990707e-43] solar,channel,battery [array([0.062168]) 1.2584961504362329 array([1.28664548])] 13222.050598374262
# net bit rate= 0.0 action [2.20388946e-43] solar,channel,battery [array([0.194232]) 1.3808462532566423 array([1.44881348])] 13109.999322116853
# net bit rate= 0.0 action [0.] solar,channel,battery [array([0.093472]) 1.3955664039811082 array([1.74304548])] 12999.83126058646
# net bit rate= 0.0 action [0.] solar,channel,battery [array([-0.031192]) 1.281355781629867 array([1.93651748])] 12891.499333414906
# Running time:  610.709536075592

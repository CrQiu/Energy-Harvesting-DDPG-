# %%
"""
Deep Deterministic Policy Gradient (DDPG), Reinforcement Learning.
P2P, net bit rate, energy harvesting example for validation.
Using:
tensorflow 1.0
"""
import tensorflow as tf
import numpy as np
import gym
import time
import EH_P2P
import math

MAX_EPISODES = 1
MAX_EP_STEPS = 100000

RENDER = False
OUTPUT_GRAPH = True

env=EH_P2P.EH_P2P()
env.Chanpower()
env.Solarread()
B=np.zeros((100,4))    

def dense(x,a,b):
    results=(x.dot(a)+b)
    return results

def choose_action(s):
    a=dense(s,a1,b1)
    a=dense(a,a3,b3)
    a=dense(a,aa,ba)
    a=1/(1+np.exp(-a))
    a = np.clip(a, 0, 1)
    return a

for snr in range (-10,-8,2):

    for epoch in range (0,1750,30):

        modulation=0

        tf.reset_default_graph()
        graph = tf.get_default_graph()
        
        saver = tf.train.import_meta_graph("folder_for_nn_noise"+"/EH_save_net_snr="+str(snr)+str(modulation)+"epoch="+str(epoch)+"_P2P.ckpt.meta")
        with tf.Session() as sess:
            saver.restore(sess,"folder_for_nn_noise"+"/EH_save_net_snr="+str(snr)+str(modulation)+"epoch="+str(epoch)+"_P2P.ckpt")

            a1 = sess.run('Actor/eval_net/l1/kernel:0')
            b1 = sess.run('Actor/eval_net/l1/bias:0')
            a3 = sess.run('Actor/eval_net/l3/kernel:0')
            b3 = sess.run('Actor/eval_net/l3/bias:0')
            aa = sess.run('Actor/eval_net/a/a/kernel:0')
            ba = sess.run('Actor/eval_net/a/a/bias:0')
    

    
            for i in range(MAX_EPISODES):

                s = env.reset_P2P(snr=snr)
                s=np.reshape(s,(1,-1))
                ep_reward = 0
                for j in range(MAX_EP_STEPS):
                    s=np.array(s,dtype=float)
                    a=choose_action(s)
                    s_, r, info = env.step_P2P([a,modulation])
                    s = s_
                    ep_reward += r
                    if (j+1)%10000==0:
                        print("net bit rate=",ep_reward/j,"snr=",snr,"modulation=",modulation, "loop =",i,"action=",a,"noise=",env.noise)
          
                index=(snr+10)/2
                B[int(index),int(modulation)]=ep_reward/j
                print(B[int(index),int(modulation)])
# Out:
# INFO:tensorflow:Restoring parameters from folder_for_nn/EH_save_net_snr=10_modulation=0.ckpt
# net bit rate= 22806.58656982205 snr= -10 modulation= 0 loop = 0 action= [1.] noise= 10.0
# net bit rate= 21968.121998283157 snr= -10 modulation= 0 loop = 0 action= [1.] noise= 10.0
# net bit rate= 21234.22203016074 snr= -10 modulation= 0 loop = 0 action= [1.] noise= 10.0
# net bit rate= 21416.792062612865 snr= -10 modulation= 0 loop = 0 action= [1.] noise= 10.0
# net bit rate= 20959.074845012707 snr= -10 modulation= 0 loop = 0 action= [1.] noise= 10.0
# net bit rate= 20761.044078519248 snr= -10 modulation= 0 loop = 0 action= [1.] noise= 10.0
# net bit rate= 21128.38351268207 snr= -10 modulation= 0 loop = 0 action= [1.] noise= 10.0
# net bit rate= 20898.42066826698 snr= -10 modulation= 0 loop = 0 action= [1.] noise= 10.0
# net bit rate= 21114.512418139715 snr= -10 modulation= 0 loop = 0 action= [0.99955193] noise= 10.0
# net bit rate= 21104.281638149318 snr= -10 modulation= 0 loop = 0 action= [1.] noise= 10.0
# 21104.281638149318
# INFO:tensorflow:Restoring parameters from folder_for_nn/EH_save_net_snr=10_modulation=0.ckpt
# net bit rate= 45324.46565365117 snr= -8 modulation= 0 loop = 0 action= [1.] noise= 6.309573444801933
# net bit rate= 44534.54619864224 snr= -8 modulation= 0 loop = 0 action= [1.] noise= 6.309573444801933
# net bit rate= 43756.853939270564 snr= -8 modulation= 0 loop = 0 action= [1.] noise= 6.309573444801933
# net bit rate= 43930.6378731569 snr= -8 modulation= 0 loop = 0 action= [1.] noise= 6.309573444801933
# net bit rate= 43266.39004740448 snr= -8 modulation= 0 loop = 0 action= [1.] noise= 6.309573444801933
# net bit rate= 43067.941205211864 snr= -8 modulation= 0 loop = 0 action= [1.] noise= 6.309573444801933
# net bit rate= 43558.634140298 snr= -8 modulation= 0 loop = 0 action= [1.] noise= 6.309573444801933
# net bit rate= 43151.0657254781 snr= -8 modulation= 0 loop = 0 action= [1.] noise= 6.309573444801933
# net bit rate= 43349.16875426913 snr= -8 modulation= 0 loop = 0 action= [0.99955193] noise= 6.309573444801933
# net bit rate= 43348.15120728865 snr= -8 modulation= 0 loop = 0 action= [1.] noise= 6.309573444801933
# 43348.15120728865
# INFO:tensorflow:Restoring parameters from folder_for_nn/EH_save_net_snr=10_modulation=0.ckpt
# net bit rate= 72579.26077044595 snr= -6 modulation= 0 loop = 0 action= [1.] noise= 3.9810717055349722
# net bit rate= 72041.71254207988 snr= -6 modulation= 0 loop = 0 action= [1.] noise= 3.9810717055349722
# net bit rate= 71418.51550621472 snr= -6 modulation= 0 loop = 0 action= [1.] noise= 3.9810717055349722
# net bit rate= 71515.06783189996 snr= -6 modulation= 0 loop = 0 action= [1.] noise= 3.9810717055349722
# net bit rate= 70923.20921798242 snr= -6 modulation= 0 loop = 0 action= [1.] noise= 3.9810717055349722
# net bit rate= 70692.82944298319 snr= -6 modulation= 0 loop = 0 action= [1.] noise= 3.9810717055349722
# net bit rate= 71501.3883206612 snr= -6 modulation= 0 loop = 0 action= [1.] noise= 3.9810717055349722
# net bit rate= 71116.65044371756 snr= -6 modulation= 0 loop = 0 action= [1.] noise= 3.9810717055349722
# net bit rate= 71245.29072691927 snr= -6 modulation= 0 loop = 0 action= [0.99955193] noise= 3.9810717055349722
# net bit rate= 71075.83634624063 snr= -6 modulation= 0 loop = 0 action= [1.] noise= 3.9810717055349722
# 71075.83634624063
# INFO:tensorflow:Restoring parameters from folder_for_nn/EH_save_net_snr=10_modulation=0.ckpt
# net bit rate= 100949.19679070017 snr= -4 modulation= 0 loop = 0 action= [1.] noise= 2.51188643150958
# net bit rate= 100636.93059165063 snr= -4 modulation= 0 loop = 0 action= [1.] noise= 2.51188643150958
# net bit rate= 100225.98813050745 snr= -4 modulation= 0 loop = 0 action= [1.] noise= 2.51188643150958
# net bit rate= 99976.86737090048 snr= -4 modulation= 0 loop = 0 action= [1.] noise= 2.51188643150958
# net bit rate= 99819.30617352389 snr= -4 modulation= 0 loop = 0 action= [1.] noise= 2.51188643150958
# net bit rate= 99477.19562689932 snr= -4 modulation= 0 loop = 0 action= [1.] noise= 2.51188643150958
# net bit rate= 100428.470581989 snr= -4 modulation= 0 loop = 0 action= [1.] noise= 2.51188643150958
# net bit rate= 100017.43709171168 snr= -4 modulation= 0 loop = 0 action= [1.] noise= 2.51188643150958
# net bit rate= 100126.9234851254 snr= -4 modulation= 0 loop = 0 action= [0.99955193] noise= 2.51188643150958
# net bit rate= 99944.98419872571 snr= -4 modulation= 0 loop = 0 action= [1.] noise= 2.51188643150958
# 99944.98419872571
# INFO:tensorflow:Restoring parameters from folder_for_nn/EH_save_net_snr=10_modulation=0.ckpt
# net bit rate= 127338.45676422294 snr= -2 modulation= 0 loop = 0 action= [1.] noise= 1.5848931924611136
# net bit rate= 126510.11186275323 snr= -2 modulation= 0 loop = 0 action= [1.] noise= 1.5848931924611136
# net bit rate= 126385.58801980899 snr= -2 modulation= 0 loop = 0 action= [1.] noise= 1.5848931924611136
# net bit rate= 126019.62497324854 snr= -2 modulation= 0 loop = 0 action= [1.] noise= 1.5848931924611136
# net bit rate= 126004.98766365097 snr= -2 modulation= 0 loop = 0 action= [1.] noise= 1.5848931924611136
# net bit rate= 125664.83290280605 snr= -2 modulation= 0 loop = 0 action= [1.] noise= 1.5848931924611136
# net bit rate= 126476.06985928275 snr= -2 modulation= 0 loop = 0 action= [1.] noise= 1.5848931924611136
# net bit rate= 126047.88324137402 snr= -2 modulation= 0 loop = 0 action= [1.] noise= 1.5848931924611136
# net bit rate= 126081.07034521832 snr= -2 modulation= 0 loop = 0 action= [0.99955193] noise= 1.5848931924611136
# net bit rate= 125999.9072497898 snr= -2 modulation= 0 loop = 0 action= [1.] noise= 1.5848931924611136
# 125999.9072497898
# INFO:tensorflow:Restoring parameters from folder_for_nn/EH_save_net_snr=10_modulation=0.ckpt
# net bit rate= 147259.75623959012 snr= 0 modulation= 0 loop = 0 action= [1.] noise= 1.0
# net bit rate= 147041.7327039902 snr= 0 modulation= 0 loop = 0 action= [1.] noise= 1.0
# net bit rate= 147368.92002093335 snr= 0 modulation= 0 loop = 0 action= [1.] noise= 1.0
# net bit rate= 147320.89376360207 snr= 0 modulation= 0 loop = 0 action= [1.] noise= 1.0
# net bit rate= 147081.84305333518 snr= 0 modulation= 0 loop = 0 action= [1.] noise= 1.0
# net bit rate= 146827.10252476932 snr= 0 modulation= 0 loop = 0 action= [1.] noise= 1.0
# net bit rate= 147446.21908227212 snr= 0 modulation= 0 loop = 0 action= [1.] noise= 1.0
# net bit rate= 147051.24927996277 snr= 0 modulation= 0 loop = 0 action= [1.] noise= 1.0
# net bit rate= 146980.71479029531 snr= 0 modulation= 0 loop = 0 action= [0.99955193] noise= 1.0
# net bit rate= 146943.91402732529 snr= 0 modulation= 0 loop = 0 action= [1.] noise= 1.0
# 146943.91402732529
# INFO:tensorflow:Restoring parameters from folder_for_nn/EH_save_net_snr=10_modulation=0.ckpt
# net bit rate= 163581.2962299446 snr= 2 modulation= 0 loop = 0 action= [1.] noise= 0.6309573444801932
# net bit rate= 163023.61149564007 snr= 2 modulation= 0 loop = 0 action= [1.] noise= 0.6309573444801932
# net bit rate= 163213.5339697716 snr= 2 modulation= 0 loop = 0 action= [1.] noise= 0.6309573444801932
# net bit rate= 163334.07656115488 snr= 2 modulation= 0 loop = 0 action= [1.] noise= 0.6309573444801932
# net bit rate= 163156.5178197314 snr= 2 modulation= 0 loop = 0 action= [1.] noise= 0.6309573444801932
# net bit rate= 163023.8942534342 snr= 2 modulation= 0 loop = 0 action= [1.] noise= 0.6309573444801932
# net bit rate= 163467.1899804227 snr= 2 modulation= 0 loop = 0 action= [1.] noise= 0.6309573444801932
# net bit rate= 163067.5717665893 snr= 2 modulation= 0 loop = 0 action= [1.] noise= 0.6309573444801932
# net bit rate= 162933.19594838255 snr= 2 modulation= 0 loop = 0 action= [0.99955193] noise= 0.6309573444801932
# net bit rate= 162838.74948084305 snr= 2 modulation= 0 loop = 0 action= [1.] noise= 0.6309573444801932
# 162838.74948084305
# INFO:tensorflow:Restoring parameters from folder_for_nn/EH_save_net_snr=10_modulation=0.ckpt
# net bit rate= 175220.84520296185 snr= 4 modulation= 0 loop = 0 action= [1.] noise= 0.3981071705534972
# net bit rate= 174703.21164729082 snr= 4 modulation= 0 loop = 0 action= [1.] noise= 0.3981071705534972
# net bit rate= 174794.23878412327 snr= 4 modulation= 0 loop = 0 action= [1.] noise= 0.3981071705534972
# net bit rate= 174908.54319910865 snr= 4 modulation= 0 loop = 0 action= [1.] noise= 0.3981071705534972
# net bit rate= 174813.45003366366 snr= 4 modulation= 0 loop = 0 action= [1.] noise= 0.3981071705534972
# net bit rate= 174738.58722930364 snr= 4 modulation= 0 loop = 0 action= [1.] noise= 0.3981071705534972
# net bit rate= 175010.3504255999 snr= 4 modulation= 0 loop = 0 action= [1.] noise= 0.3981071705534972
# net bit rate= 174714.9292100338 snr= 4 modulation= 0 loop = 0 action= [1.] noise= 0.3981071705534972
# net bit rate= 174618.56516651766 snr= 4 modulation= 0 loop = 0 action= [0.99955193] noise= 0.3981071705534972
# net bit rate= 174545.79420858814 snr= 4 modulation= 0 loop = 0 action= [1.] noise= 0.3981071705534972
# 174545.79420858814
# INFO:tensorflow:Restoring parameters from folder_for_nn/EH_save_net_snr=10_modulation=0.ckpt
# net bit rate= 183292.52836938895 snr= 6 modulation= 0 loop = 0 action= [1.] noise= 0.251188643150958
# net bit rate= 182973.17165754584 snr= 6 modulation= 0 loop = 0 action= [1.] noise= 0.251188643150958
# net bit rate= 183046.42354909793 snr= 6 modulation= 0 loop = 0 action= [1.] noise= 0.251188643150958
# net bit rate= 183109.42902031797 snr= 6 modulation= 0 loop = 0 action= [1.] noise= 0.251188643150958
# net bit rate= 183018.45869093365 snr= 6 modulation= 0 loop = 0 action= [1.] noise= 0.251188643150958
# net bit rate= 182921.08742349778 snr= 6 modulation= 0 loop = 0 action= [1.] noise= 0.251188643150958
# net bit rate= 183042.55748818166 snr= 6 modulation= 0 loop = 0 action= [1.] noise= 0.251188643150958
# net bit rate= 182821.81601367588 snr= 6 modulation= 0 loop = 0 action= [1.] noise= 0.251188643150958
# net bit rate= 182747.5191842054 snr= 6 modulation= 0 loop = 0 action= [0.99955193] noise= 0.251188643150958
# net bit rate= 182706.27138565667 snr= 6 modulation= 0 loop = 0 action= [1.] noise= 0.251188643150958
# 182706.27138565667
# INFO:tensorflow:Restoring parameters from folder_for_nn/EH_save_net_snr=10_modulation=0.ckpt
# net bit rate= 188680.60263628635 snr= 8 modulation= 0 loop = 0 action= [1.] noise= 0.15848931924611134
# net bit rate= 188527.2459028832 snr= 8 modulation= 0 loop = 0 action= [1.] noise= 0.15848931924611134
# net bit rate= 188547.2338187103 snr= 8 modulation= 0 loop = 0 action= [1.] noise= 0.15848931924611134
# net bit rate= 188591.08935549064 snr= 8 modulation= 0 loop = 0 action= [1.] noise= 0.15848931924611134
# net bit rate= 188592.61065721445 snr= 8 modulation= 0 loop = 0 action= [1.] noise= 0.15848931924611134
# net bit rate= 188502.55662464656 snr= 8 modulation= 0 loop = 0 action= [1.] noise= 0.15848931924611134
# net bit rate= 188546.68454503425 snr= 8 modulation= 0 loop = 0 action= [1.] noise= 0.15848931924611134
# net bit rate= 188421.6132435828 snr= 8 modulation= 0 loop = 0 action= [1.] noise= 0.15848931924611134
# net bit rate= 188348.25775965158 snr= 8 modulation= 0 loop = 0 action= [0.99955193] noise= 0.15848931924611134
# net bit rate= 188310.08819378327 snr= 8 modulation= 0 loop = 0 action= [1.] noise= 0.15848931924611134
# 188310.08819378327
# INFO:tensorflow:Restoring parameters from folder_for_nn/EH_save_net_snr=10_modulation=0.ckpt
# net bit rate= 192369.5378286829 snr= 10 modulation= 0 loop = 0 action= [1.] noise= 0.1
# net bit rate= 192283.01386841084 snr= 10 modulation= 0 loop = 0 action= [1.] noise= 0.1
# net bit rate= 192305.55220862196 snr= 10 modulation= 0 loop = 0 action= [1.] noise= 0.1
# net bit rate= 192328.88186616555 snr= 10 modulation= 0 loop = 0 action= [1.] noise= 0.1
# net bit rate= 192320.5203595834 snr= 10 modulation= 0 loop = 0 action= [1.] noise= 0.1
# net bit rate= 192230.85911031996 snr= 10 modulation= 0 loop = 0 action= [1.] noise= 0.1
# net bit rate= 192232.87016181077 snr= 10 modulation= 0 loop = 0 action= [1.] noise= 0.1
# net bit rate= 192167.39334236828 snr= 10 modulation= 0 loop = 0 action= [1.] noise= 0.1
# net bit rate= 192101.6344240434 snr= 10 modulation= 0 loop = 0 action= [0.99955193] noise= 0.1
# net bit rate= 192072.19625227028 snr= 10 modulation= 0 loop = 0 action= [1.] noise= 0.1
# 192072.19625227028
# INFO:tensorflow:Restoring parameters from folder_for_nn/EH_save_net_snr=10_modulation=0.ckpt
# net bit rate= 194990.42824052973 snr= 12 modulation= 0 loop = 0 action= [1.] noise= 0.06309573444801933
# net bit rate= 194770.58663868284 snr= 12 modulation= 0 loop = 0 action= [1.] noise= 0.06309573444801933
# net bit rate= 194794.03865379942 snr= 12 modulation= 0 loop = 0 action= [1.] noise= 0.06309573444801933
# net bit rate= 194786.27739803758 snr= 12 modulation= 0 loop = 0 action= [1.] noise= 0.06309573444801933
# net bit rate= 194773.87682632517 snr= 12 modulation= 0 loop = 0 action= [1.] noise= 0.06309573444801933
# net bit rate= 194652.8162402164 snr= 12 modulation= 0 loop = 0 action= [1.] noise= 0.06309573444801933
# net bit rate= 194653.1933021458 snr= 12 modulation= 0 loop = 0 action= [1.] noise= 0.06309573444801933
# net bit rate= 194604.9021429305 snr= 12 modulation= 0 loop = 0 action= [1.] noise= 0.06309573444801933
# net bit rate= 194552.96450948602 snr= 12 modulation= 0 loop = 0 action= [0.99955193] noise= 0.06309573444801933
# net bit rate= 194526.4855436799 snr= 12 modulation= 0 loop = 0 action= [1.] noise= 0.06309573444801933
# 194526.4855436799
# INFO:tensorflow:Restoring parameters from folder_for_nn/EH_save_net_snr=10_modulation=0.ckpt
# net bit rate= 196614.07819101983 snr= 14 modulation= 0 loop = 0 action= [1.] noise= 0.039810717055349734
# net bit rate= 196381.82701865654 snr= 14 modulation= 0 loop = 0 action= [1.] noise= 0.039810717055349734
# net bit rate= 196359.83165919338 snr= 14 modulation= 0 loop = 0 action= [1.] noise= 0.039810717055349734
# net bit rate= 196348.22080805092 snr= 14 modulation= 0 loop = 0 action= [1.] noise= 0.039810717055349734
# net bit rate= 196303.6809651237 snr= 14 modulation= 0 loop = 0 action= [1.] noise= 0.039810717055349734
# net bit rate= 196195.0946837163 snr= 14 modulation= 0 loop = 0 action= [1.] noise= 0.039810717055349734
# net bit rate= 196224.51332482335 snr= 14 modulation= 0 loop = 0 action= [1.] noise= 0.039810717055349734
# net bit rate= 196204.73911525606 snr= 14 modulation= 0 loop = 0 action= [1.] noise= 0.039810717055349734
# net bit rate= 196174.33934470903 snr= 14 modulation= 0 loop = 0 action= [0.99955193] noise= 0.039810717055349734
# net bit rate= 196166.3814926025 snr= 14 modulation= 0 loop = 0 action= [1.] noise= 0.039810717055349734
# 196166.3814926025
# INFO:tensorflow:Restoring parameters from folder_for_nn/EH_save_net_snr=10_modulation=0.ckpt
# net bit rate= 197603.42767692095 snr= 16 modulation= 0 loop = 0 action= [1.] noise= 0.025118864315095794
# net bit rate= 197467.62049688323 snr= 16 modulation= 0 loop = 0 action= [1.] noise= 0.025118864315095794
# net bit rate= 197372.83105611327 snr= 16 modulation= 0 loop = 0 action= [1.] noise= 0.025118864315095794
# net bit rate= 197378.2773640724 snr= 16 modulation= 0 loop = 0 action= [1.] noise= 0.025118864315095794
# net bit rate= 197335.29474583824 snr= 16 modulation= 0 loop = 0 action= [1.] noise= 0.025118864315095794
# net bit rate= 197261.0508435008 snr= 16 modulation= 0 loop = 0 action= [1.] noise= 0.025118864315095794
# net bit rate= 197294.12897903242 snr= 16 modulation= 0 loop = 0 action= [1.] noise= 0.025118864315095794
# net bit rate= 197272.08953478714 snr= 16 modulation= 0 loop = 0 action= [1.] noise= 0.025118864315095794
# net bit rate= 197267.67730390324 snr= 16 modulation= 0 loop = 0 action= [0.99955193] noise= 0.025118864315095794
# net bit rate= 197276.75422591504 snr= 16 modulation= 0 loop = 0 action= [1.] noise= 0.025118864315095794
# 197276.75422591504
# INFO:tensorflow:Restoring parameters from folder_for_nn/EH_save_net_snr=10_modulation=0.ckpt
# net bit rate= 198335.81663958033 snr= 18 modulation= 0 loop = 0 action= [1.] noise= 0.015848931924611134
# net bit rate= 198190.44268413194 snr= 18 modulation= 0 loop = 0 action= [1.] noise= 0.015848931924611134
# net bit rate= 198091.10299171138 snr= 18 modulation= 0 loop = 0 action= [1.] noise= 0.015848931924611134
# net bit rate= 198071.71575783027 snr= 18 modulation= 0 loop = 0 action= [1.] noise= 0.015848931924611134
# net bit rate= 198022.14829470264 snr= 18 modulation= 0 loop = 0 action= [1.] noise= 0.015848931924611134
# net bit rate= 197965.1219356738 snr= 18 modulation= 0 loop = 0 action= [1.] noise= 0.015848931924611134
# net bit rate= 198009.6711940336 snr= 18 modulation= 0 loop = 0 action= [1.] noise= 0.015848931924611134
# net bit rate= 198015.92255713607 snr= 18 modulation= 0 loop = 0 action= [1.] noise= 0.015848931924611134
# net bit rate= 198013.44138716854 snr= 18 modulation= 0 loop = 0 action= [0.99955193] noise= 0.015848931924611134
# net bit rate= 198035.8272327469 snr= 18 modulation= 0 loop = 0 action= [1.] noise= 0.015848931924611134
# 198035.8272327469
# INFO:tensorflow:Restoring parameters from folder_for_nn/EH_save_net_snr=10_modulation=0.ckpt
# net bit rate= 198824.6154126743 snr= 20 modulation= 0 loop = 0 action= [1.] noise= 0.01
# net bit rate= 198664.1367752849 snr= 20 modulation= 0 loop = 0 action= [1.] noise= 0.01
# net bit rate= 198578.37543236717 snr= 20 modulation= 0 loop = 0 action= [1.] noise= 0.01
# net bit rate= 198570.62882117133 snr= 20 modulation= 0 loop = 0 action= [1.] noise= 0.01
# net bit rate= 198514.1198574112 snr= 20 modulation= 0 loop = 0 action= [1.] noise= 0.01
# net bit rate= 198459.9765823737 snr= 20 modulation= 0 loop = 0 action= [1.] noise= 0.01
# net bit rate= 198492.2192285054 snr= 20 modulation= 0 loop = 0 action= [1.] noise= 0.01
# net bit rate= 198503.46304247165 snr= 20 modulation= 0 loop = 0 action= [1.] noise= 0.01
# net bit rate= 198496.99881824516 snr= 20 modulation= 0 loop = 0 action= [0.99955193] noise= 0.01
# net bit rate= 198525.01431045713 snr= 20 modulation= 0 loop = 0 action= [1.] noise= 0.01
# 198525.01431045713

# %%
print(B)

# %%
np.savetxt("DDPG_P2P_noise2"+str(snr)+".csv", B, delimiter = ',')
